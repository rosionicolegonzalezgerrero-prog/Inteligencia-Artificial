# %% [markdown]
# <a href="https://colab.research.google.com/github/rosionicolegonzalezgerrero-prog/Inteligencia-Artificial/blob/main/ACF8_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AF7: Redes Neuronales Artificiales
# IMC 2098337 Rosio Nicole Gonzalez Guerrero V6
# IMC 2095410 Jesus Valdez Hurtado N5
# IMC 2103795 Diego Nedved Saucedo de la Torre N5

# %% [markdown]
# 1.-Cargamos las librerías

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import random
from IPython.display import display, HTML
from PIL import Image
import io
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
import base64
import pandas as pd

# %% [markdown]
# 2.-Cargamos los datos

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("Shape of x_train:", x_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %% [markdown]
# 3.-Procesamos los datos

# %%
# Preprocesamos los datos
# Normalizamos las imágenes a un rango de 0 a 1
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Reshape las imágenes para incluir la dimensión del canal (1 para escala de grises)
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)


# Convertimos las etiquetas a formato categórico (one-hot encoding)
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print("Shape of x_train after preprocessing:", x_train.shape)
print("Shape of y_train after preprocessing:", y_train.shape)
print("Shape of x_test after preprocessing:", x_test.shape)
print("Shape of y_test after preprocessing:", y_test.shape)
# Out:
# Shape of x_train after preprocessing: (60000, 28, 28, 1)
# Shape of y_train after preprocessing: (60000, 10)
# Shape of x_test after preprocessing: (10000, 28, 28, 1)
# Shape of y_test after preprocessing: (10000, 10)

# %% [markdown]
# 4.-Selección y entrenamiento del modelo

# %%
# Definimos el modelo CNN
model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, kernel_size=(3, 3), activation='relu'), # Capa convolucional con 32 filtros
    MaxPooling2D(pool_size=(2, 2)), # Capa de pooling para reducir la dimensionalidad
    Conv2D(64, kernel_size=(3, 3), activation='relu'), # Otra capa convolucional con 64 filtros
    MaxPooling2D(pool_size=(2, 2)), # Otra capa de pooling
    Flatten(),  # Capa de aplanamiento antes de las capas densas
    Dense(128, activation='relu'), # Capa densa
    Dense(10, activation='softmax') # Capa de salida
])

# Compilamos el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# Entrenamos el modelo CNN
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluamos el modelo en el conjunto de prueba
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

print(f'\nPrecisión del modelo en el conjunto de prueba: {accuracy:.4f}')
print(f'Pérdida del modelo en el conjunto de prueba: {loss:.4f}')
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 48s 31ms/step - accuracy: 0.9535 - loss: 0.1487 - val_accuracy: 0.9799 - val_loss: 0.0658
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 80s 30ms/step - accuracy: 0.9846 - loss: 0.0494 - val_accuracy: 0.9842 - val_loss: 0.0536
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9897 - loss: 0.0334 - val_accuracy: 0.9872 - val_loss: 0.0438
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9923 - loss: 0.0239 - val_accuracy: 0.9885 - val_loss: 0.0379
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 84s 30ms/step - accuracy: 0.9946 - loss: 0.0167 - val_accuracy: 0.9870 - val_loss: 0.0503
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9957 - loss: 0.0139 - val_accuracy: 0.9906 - val_loss: 0.0351
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 44s 29ms/step - accuracy: 0.9962 - loss: 0.0112 - val_accuracy: 0.9884 - val_loss: 0.0421
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9971 - loss: 0.0082 - val_accuracy: 0.9885 - val_loss: 0.0492
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 83s 29ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9883 - val_loss: 0.0513
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9904 - val_loss: 0.0453
#
# Precisión del modelo en el conjunto de prueba: 0.9902
# Pérdida del modelo en el conjunto de prueba: 0.0419

# %% [markdown]
# 5.-Prueba del modelo

# %%
# Seleccionamos 5 índices aleatorios del conjunto de prueba
num_predictions = 5
random_indices = random.sample(range(len(x_test)), num_predictions)

true_labels = []
predicted_labels = []
images = []

for img_index in random_indices:
    test_image = x_test[img_index]
    true_label = np.argmax(y_test[img_index])
    true_labels.append(true_label)

    # Expandimos las dimensiones para que coincida con el formato de entrada del modelo (batch size de 1)
    test_image_input = np.expand_dims(test_image, axis=0)

    # Hacemos la predicción
    predictions = model.predict(test_image_input)
    predicted_label = np.argmax(predictions[0])
    predicted_labels.append(predicted_label)

    # Convertir la imagen de NumPy a PIL y luego a base64 para mostrar en HTML
    img_array = (test_image.reshape(28, 28) * 255).astype(np.uint8)
    img = Image.fromarray(img_array)
    img_byte_arr = io.BytesIO()
    img.save(img_byte_arr, format='PNG')
    img_base64 = base64.b64encode(img_byte_arr.getvalue()).decode('ascii')
    images.append(f'')


# Mostramos los resultados en una tabla HTML con imágenes
results_df = pd.DataFrame({'Imagen': images, 'Etiqueta Real': true_labels, 'Predicción': predicted_labels})

# Mostramos la tabla usando display y permitiendo HTML
display(HTML(results_df.to_html(escape=False)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Imagen</th>
#       <th>Etiqueta Real</th>
#       <th>Predicción</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td></td>
#       <td>6</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td></td>
#       <td>9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
